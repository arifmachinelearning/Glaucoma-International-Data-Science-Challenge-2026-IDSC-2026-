# %%
"""
=============================================================
  Eye Image Quality Score Regression - Training Script
  Model     : MobileNetV2 (~3.4M params)
  Loss      : Huber Loss
  Optimizer : AdamW + CosineAnnealingLR
  Strategy  : 2-Phase training (freeze → unfreeze)
  Split     : 80 / 10 / 10  (train / val / test)
=============================================================
"""

import os
import random
import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from torch.optim.lr_scheduler import CosineAnnealingLR

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

import matplotlib.pyplot as plt
from tqdm import tqdm
import warnings
warnings.filterwarnings("ignore")

# ─────────────────────────────────────────────
# 0.  REPRODUCIBILITY
# ─────────────────────────────────────────────
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

# ─────────────────────────────────────────────
# 1.  CONFIG  ← tukar path di sini
# ─────────────────────────────────────────────
CSV_PATH   = r"C:\Users\PC\Desktop\Image_Regresion\dataset\dataset\Labels.csv"
IMG_DIR    = r"C:\Users\PC\Desktop\Image_Regresion\dataset\dataset\Images"
SAVE_DIR   = r"C:\Users\PC\Desktop\Image_Regresion\outputs"

IMG_SIZE   = 224
BATCH_SIZE = 16
NUM_EPOCHS_PHASE1 = 10    # freeze backbone
NUM_EPOCHS_PHASE2 = 50    # unfreeze all
LR_PHASE1  = 1e-3
LR_PHASE2  = 1e-4
WEIGHT_DECAY = 1e-4
PATIENCE   = 10           # early stopping

os.makedirs(SAVE_DIR, exist_ok=True)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {DEVICE}")

# ─────────────────────────────────────────────
# 2.  LOAD & INSPECT CSV
# ─────────────────────────────────────────────
df = pd.read_csv(CSV_PATH)
print("\n── CSV columns ──")
print(df.columns.tolist())
print(df.head())

# Auto-detect column names (flexible)
img_col   = df.columns[0]   # Image Name
score_col = df.columns[3]   # Quality Score  (index 3 = col D)

print(f"\nImage column   : '{img_col}'")
print(f"Score column   : '{score_col}'")
print(f"Score range    : {df[score_col].min():.3f}  →  {df[score_col].max():.3f}")
print(f"Score mean±std : {df[score_col].mean():.3f} ± {df[score_col].std():.3f}")
print(f"Total samples  : {len(df)}")

# Normalize score to [0, 1] for stable training
SCORE_MIN = df[score_col].min()
SCORE_MAX = df[score_col].max()
df["score_norm"] = (df[score_col] - SCORE_MIN) / (SCORE_MAX - SCORE_MIN)

# ─────────────────────────────────────────────
# 3.  TRAIN / VAL / TEST SPLIT  (80/10/10)
# ─────────────────────────────────────────────
train_df, temp_df = train_test_split(df, test_size=0.20, random_state=SEED)
val_df,   test_df = train_test_split(temp_df, test_size=0.50, random_state=SEED)

print(f"\nSplit → Train: {len(train_df)} | Val: {len(val_df)} | Test: {len(test_df)}")

# ─────────────────────────────────────────────
# 4.  DATASET
# ─────────────────────────────────────────────
class EyeDataset(Dataset):
    def __init__(self, dataframe, img_dir, transform=None):
        self.df        = dataframe.reset_index(drop=True)
        self.img_dir   = img_dir
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row      = self.df.iloc[idx]
        img_path = os.path.join(self.img_dir, row[img_col])
        image    = Image.open(img_path).convert("RGB")
        if self.transform:
            image = self.transform(image)
        score = torch.tensor(row["score_norm"], dtype=torch.float32)
        return image, score


# Augmentation for TRAIN only
train_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.RandomRotation(degrees=15),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.2),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std =[0.229, 0.224, 0.225]),
])

val_transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std =[0.229, 0.224, 0.225]),
])

train_ds = EyeDataset(train_df, IMG_DIR, train_transform)
val_ds   = EyeDataset(val_df,   IMG_DIR, val_transform)
test_ds  = EyeDataset(test_df,  IMG_DIR, val_transform)

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True,  num_workers=0, pin_memory=True)
val_loader   = DataLoader(val_ds,   batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
test_loader  = DataLoader(test_ds,  batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)

# ─────────────────────────────────────────────
# 5.  MODEL  (MobileNetV2 regression head)
# ─────────────────────────────────────────────
class MobileNetV2Regressor(nn.Module):
    def __init__(self, pretrained=True):
        super().__init__()
        weights   = models.MobileNet_V2_Weights.DEFAULT if pretrained else None
        backbone  = models.mobilenet_v2(weights=weights)
        self.features = backbone.features          # output: (B, 1280, 7, 7)
        self.pool     = nn.AdaptiveAvgPool2d(1)    # → (B, 1280, 1, 1)
        self.head     = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.3),
            nn.Linear(1280, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()                           # output in [0,1] (normalised score)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x)
        x = self.head(x)
        return x.squeeze(1)                        # (B,)

    def freeze_backbone(self):
        for p in self.features.parameters():
            p.requires_grad = False

    def unfreeze_backbone(self):
        for p in self.features.parameters():
            p.requires_grad = True


model = MobileNetV2Regressor(pretrained=True).to(DEVICE)
total_params = sum(p.numel() for p in model.parameters())
print(f"\nTotal parameters : {total_params:,}  (~{total_params/1e6:.1f}M)")

# ─────────────────────────────────────────────
# 6.  LOSS & HELPERS
# ─────────────────────────────────────────────
criterion = nn.HuberLoss(delta=0.1)   # robust to outliers

def compute_metrics(preds_norm, targets_norm):
    """Return MAE, RMSE, R² in original score scale."""
    p = preds_norm   * (SCORE_MAX - SCORE_MIN) + SCORE_MIN
    t = targets_norm * (SCORE_MAX - SCORE_MIN) + SCORE_MIN
    mae  = np.mean(np.abs(p - t))
    rmse = np.sqrt(np.mean((p - t) ** 2))
    r2   = r2_score(t, p)
    return mae, rmse, r2

# ─────────────────────────────────────────────
# 7.  TRAINING LOOP
# ─────────────────────────────────────────────
def run_epoch(loader, train=True, optimizer=None, epoch=None, num_epochs=None, phase=None):
    model.train() if train else model.eval()
    total_loss, all_preds, all_targets = 0.0, [], []

    ctx = torch.enable_grad() if train else torch.no_grad()
    with ctx:
        for imgs, scores in loader:
            imgs, scores = imgs.to(DEVICE), scores.to(DEVICE)
            preds = model(imgs)
            loss  = criterion(preds, scores)
            if train:
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
            total_loss   += loss.item() * len(imgs)
            all_preds    += preds.detach().cpu().tolist()
            all_targets  += scores.cpu().tolist()

    avg_loss = total_loss / len(loader.dataset)
    mae, rmse, r2 = compute_metrics(np.array(all_preds), np.array(all_targets))
    return avg_loss, mae, rmse, r2


def train_phase(num_epochs, lr, phase_name, phase_short):
    optimizer = torch.optim.AdamW(
        filter(lambda p: p.requires_grad, model.parameters()),
        lr=lr, weight_decay=WEIGHT_DECAY
    )
    scheduler   = CosineAnnealingLR(optimizer, T_max=num_epochs, eta_min=lr * 0.01)
    best_val_loss = float("inf")
    patience_cnt  = 0
    history       = {"train_loss": [], "val_loss": [], "val_mae": [], "val_r2": []}

    print(f"\n{'='*65}")
    print(f"  {phase_name}")
    print(f"{'='*65}")

    epoch_bar = tqdm(range(1, num_epochs + 1), desc=f"  {phase_short}", unit="epoch",
                     bar_format="{l_bar}{bar:30}{r_bar}")

    for epoch in epoch_bar:
        tr_loss, tr_mae, tr_rmse, tr_r2 = run_epoch(train_loader, train=True,  optimizer=optimizer,
                                                      epoch=epoch, num_epochs=num_epochs, phase=phase_short)
        vl_loss, vl_mae, vl_rmse, vl_r2 = run_epoch(val_loader,   train=False,
                                                      epoch=epoch, num_epochs=num_epochs, phase=phase_short)
        scheduler.step()

        history["train_loss"].append(tr_loss)
        history["val_loss"].append(vl_loss)
        history["val_mae"].append(vl_mae)
        history["val_r2"].append(vl_r2)

        # Update outer epoch bar with summary metrics
        epoch_bar.set_postfix({
            "TrLoss": f"{tr_loss:.4f}",
            "VlLoss": f"{vl_loss:.4f}",
            "VlMAE" : f"{vl_mae:.4f}",
            "R²"    : f"{vl_r2:.4f}",
            "best"  : "✅" if vl_loss < best_val_loss else f"⏳{patience_cnt+1}/{PATIENCE}"
        })

        # Save best
        if vl_loss < best_val_loss:
            best_val_loss = vl_loss
            patience_cnt  = 0
            save_path = os.path.join(SAVE_DIR, "best_model.pth")
            os.makedirs(SAVE_DIR, exist_ok=True)   # pastikan folder wujud
            try:
                torch.save(model.state_dict(), save_path)
                tqdm.write(f"  💾 Model saved → {save_path}")
            except Exception as e:
                tqdm.write(f"  ❌ SAVE FAILED: {e}")
        else:
            patience_cnt += 1
            if patience_cnt >= PATIENCE:
                tqdm.write(f"  ⚠ Early stopping triggered at epoch {epoch}")
                break

    return history


# ── Phase 1: frozen backbone ──────────────────
model.freeze_backbone()
h1 = train_phase(NUM_EPOCHS_PHASE1, LR_PHASE1,
                 "PHASE 1 – Train head only (backbone frozen)", "P1")

# ── Phase 2: full fine-tune ───────────────────
model.unfreeze_backbone()
h2 = train_phase(NUM_EPOCHS_PHASE2, LR_PHASE2,
                 "PHASE 2 – Full fine-tune (all layers)", "P2")

# ── Save final weights (last epoch) ──────────
final_path = os.path.join(SAVE_DIR, "final_model.pth")
os.makedirs(SAVE_DIR, exist_ok=True)
torch.save(model.state_dict(), final_path)
print(f"\n💾 Final model saved → {final_path}")

# ─────────────────────────────────────────────
# 8.  TEST EVALUATION
# ─────────────────────────────────────────────
print("\n── Loading best model for test evaluation ──")
model.load_state_dict(torch.load(os.path.join(SAVE_DIR, "best_model.pth"), map_location=DEVICE))

ts_loss, ts_mae, ts_rmse, ts_r2 = run_epoch(test_loader, train=False, phase="TEST")
print(f"\n{'='*55}")
print(f"  TEST RESULTS")
print(f"  Loss (Huber) : {ts_loss:.4f}")
print(f"  MAE          : {ts_mae:.4f}")
print(f"  RMSE         : {ts_rmse:.4f}")
print(f"  R²           : {ts_r2:.4f}")
print(f"{'='*55}")

# ─────────────────────────────────────────────
# 9.  PLOTS
# ─────────────────────────────────────────────
# Combine phase histories
all_train_loss = h1["train_loss"] + h2["train_loss"]
all_val_loss   = h1["val_loss"]   + h2["val_loss"]
all_val_mae    = h1["val_mae"]    + h2["val_mae"]

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# (a) Loss curves
axes[0].plot(all_train_loss, label="Train Loss")
axes[0].plot(all_val_loss,   label="Val Loss")
axes[0].axvline(len(h1["train_loss"]) - 1, color="gray", linestyle="--", label="Phase 2 start")
axes[0].set_title("Huber Loss Curve")
axes[0].set_xlabel("Epoch"); axes[0].set_ylabel("Loss")
axes[0].legend(); axes[0].grid(True)

# (b) Val MAE
axes[1].plot(all_val_mae, color="orange", label="Val MAE")
axes[1].set_title("Validation MAE")
axes[1].set_xlabel("Epoch"); axes[1].set_ylabel("MAE (original scale)")
axes[1].legend(); axes[1].grid(True)

# (c) Prediction vs Actual (test set)
model.eval()
all_p, all_t = [], []
with torch.no_grad():
    for imgs, scores in test_loader:
        imgs = imgs.to(DEVICE)
        preds = model(imgs).cpu().numpy()
        all_p += list(preds   * (SCORE_MAX - SCORE_MIN) + SCORE_MIN)
        all_t += list(scores.numpy() * (SCORE_MAX - SCORE_MIN) + SCORE_MIN)

all_p, all_t = np.array(all_p), np.array(all_t)
axes[2].scatter(all_t, all_p, alpha=0.7, edgecolors="k", linewidths=0.5)
lims = [min(all_t.min(), all_p.min()) - 0.3,
        max(all_t.max(), all_p.max()) + 0.3]
axes[2].plot(lims, lims, "r--", label="Perfect prediction")
axes[2].set_xlim(lims); axes[2].set_ylim(lims)
axes[2].set_title(f"Predicted vs Actual  (R²={ts_r2:.3f})")
axes[2].set_xlabel("Actual Score"); axes[2].set_ylabel("Predicted Score")
axes[2].legend(); axes[2].grid(True)

plt.tight_layout()
fig.savefig(os.path.join(SAVE_DIR, "training_results.png"), dpi=150)
plt.show()
print(f"\n✅ Plot saved → {SAVE_DIR}\\training_results.png")
print(f"✅ Best model → {SAVE_DIR}\\best_model.pth")
# Out:
# Using device: cuda
#
# ── CSV columns ──
# ['Image Name', 'Patient', 'Label', 'Quality Score', 'Unnamed: 4']
#   Image Name  Patient Label  Quality Score  Unnamed: 4
# 0    0_0.jpg        0  GON+           6.18         NaN
# 1    1_0.jpg        1  GON+           5.31         NaN
# 2    1_1.jpg        1  GON+           4.37         NaN
# 3    2_0.jpg        2  GON+           3.51         NaN
# 4    2_1.jpg        2  GON+           4.24         NaN
#
# Image column   : 'Image Name'
# Score column   : 'Quality Score'
# Score range    : 2.040  →  7.690
# Score mean±std : 5.904 ± 1.007
# Total samples  : 747
#
# Split → Train: 597 | Val: 75 | Test: 75
#
# Total parameters : 2,552,065  (~2.6M)
#
# =================================================================
#   PHASE 1 – Train head only (backbone frozen)
# =================================================================
#   P1:  10%|███                           | 1/10 [00:24<03:41, 24.67s/epoch, TrLoss=0.0087, VlLoss=0.0076, VlMAE=0.6750, R²=0.0149, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P1:  20%|██████                        | 2/10 [00:49<03:16, 24.61s/epoch, TrLoss=0.0073, VlLoss=0.0052, VlMAE=0.5156, R²=0.3595, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P1:  30%|█████████                     | 3/10 [01:13<02:52, 24.60s/epoch, TrLoss=0.0068, VlLoss=0.0043, VlMAE=0.4354, R²=0.4549, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P1:  40%|████████████                  | 4/10 [01:39<02:29, 24.84s/epoch, TrLoss=0.0065, VlLoss=0.0042, VlMAE=0.4267, R²=0.4559, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P1:  50%|███████████████               | 5/10 [02:03<02:03, 24.65s/epoch, TrLoss=0.0062, VlLoss=0.0041, VlMAE=0.4212, R²=0.4727, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P1:  70%|█████████████████████         | 7/10 [02:52<01:13, 24.55s/epoch, TrLoss=0.0056, VlLoss=0.0040, VlMAE=0.4311, R²=0.5178, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P1: 100%|██████████████████████████████| 10/10 [04:04<00:00, 24.47s/epoch, TrLoss=0.0061, VlLoss=0.0041, VlMAE=0.4279, R²=0.5002, best=⏳3/10]
# =================================================================
#   PHASE 2 – Full fine-tune (all layers)
# =================================================================
#   P2:   2%|▌                             | 1/50 [00:24<19:43, 24.16s/epoch, TrLoss=0.0055, VlLoss=0.0042, VlMAE=0.4225, R²=0.4890, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:   4%|█▏                            | 2/50 [00:48<19:18, 24.14s/epoch, TrLoss=0.0050, VlLoss=0.0039, VlMAE=0.4088, R²=0.5226, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  10%|███                           | 5/50 [02:00<18:00, 24.02s/epoch, TrLoss=0.0039, VlLoss=0.0039, VlMAE=0.4140, R²=0.5235, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  12%|███▌                          | 6/50 [02:24<17:36, 24.00s/epoch, TrLoss=0.0038, VlLoss=0.0035, VlMAE=0.3961, R²=0.5905, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  14%|████▏                         | 7/50 [02:48<17:10, 23.96s/epoch, TrLoss=0.0039, VlLoss=0.0034, VlMAE=0.3728, R²=0.5918, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  16%|████▊                         | 8/50 [03:11<16:39, 23.79s/epoch, TrLoss=0.0037, VlLoss=0.0033, VlMAE=0.3693, R²=0.6036, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  18%|█████▍                        | 9/50 [03:34<16:11, 23.70s/epoch, TrLoss=0.0038, VlLoss=0.0031, VlMAE=0.3602, R²=0.6352, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  20%|██████                        | 10/50 [03:58<15:43, 23.59s/epoch, TrLoss=0.0032, VlLoss=0.0030, VlMAE=0.3438, R²=0.6343, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  22%|██████▌                       | 11/50 [04:22<15:23, 23.69s/epoch, TrLoss=0.0035, VlLoss=0.0028, VlMAE=0.3549, R²=0.6686, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  24%|███████▏                      | 12/50 [04:46<15:03, 23.78s/epoch, TrLoss=0.0033, VlLoss=0.0027, VlMAE=0.3332, R²=0.6746, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  26%|███████▊                      | 13/50 [05:09<14:40, 23.78s/epoch, TrLoss=0.0030, VlLoss=0.0026, VlMAE=0.3290, R²=0.6883, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  28%|████████▍                     | 14/50 [05:34<14:20, 23.91s/epoch, TrLoss=0.0033, VlLoss=0.0026, VlMAE=0.3199, R²=0.6962, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  30%|█████████                     | 15/50 [05:58<13:56, 23.89s/epoch, TrLoss=0.0032, VlLoss=0.0025, VlMAE=0.3125, R²=0.7111, best=✅]
#   💾 Model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#   P2:  48%|██████████████▍               | 24/50 [09:57<10:47, 24.89s/epoch, TrLoss=0.0025, VlLoss=0.0030, VlMAE=0.3533, R²=0.6315, best=⏳10/10]
#   ⚠ Early stopping triggered at epoch 25
#
# 💾 Final model saved → C:\Users\PC\Desktop\Image_Regresion\outputs\final_model.pth
#
# ── Loading best model for test evaluation ──
#
# =======================================================
#   TEST RESULTS
#   Loss (Huber) : 0.0039
#   MAE          : 0.4234
#   RMSE         : 0.5425
#   R²           : 0.6858
# =======================================================
# ✅ Plot saved → C:\Users\PC\Desktop\Image_Regresion\outputs\training_results.png
# ✅ Best model → C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth

# %%
"""
=============================================================
  Eye Image Quality Score Regression - Inference Script
  - Predict semua gambar + label split (Train/Val/Test)
  - Evaluation metrics untuk Val & Test sahaja
  - Visualize 5 random gambar dari Test set
=============================================================
"""

import os
import random
import numpy as np
import pandas as pd
from PIL import Image
from pathlib import Path
from tqdm import tqdm

import torch
import torch.nn as nn
from torchvision import transforms, models
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# ─────────────────────────────────────────────
# CONFIG ← tukar path di sini
# ─────────────────────────────────────────────
MODEL_PATH  = r"C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth"
CSV_PATH    = r"C:\Users\PC\Desktop\Image_Regresion\dataset\dataset\Labels.csv"
PREDICT_DIR = r"C:\Users\PC\Desktop\Image_Regresion\dataset\dataset\Images"

IMG_SIZE    = 224
SEED        = 42   # MESTI sama dengan train.py
DEVICE      = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {DEVICE}")

# ─────────────────────────────────────────────
# LOAD CSV + REPRODUCE SPLIT (sama macam train.py)
# ─────────────────────────────────────────────
df        = pd.read_csv(CSV_PATH)
img_col   = df.columns[0]
score_col = df.columns[3]
SCORE_MIN = df[score_col].min()
SCORE_MAX = df[score_col].max()
print(f"Score range: {SCORE_MIN:.3f} → {SCORE_MAX:.3f}")

# Reproduce exact same split dengan SEED yang sama
train_df, temp_df = train_test_split(df, test_size=0.20, random_state=SEED)
val_df,   test_df = train_test_split(temp_df, test_size=0.50, random_state=SEED)

# Buat lookup: filename → split label
split_lookup = {}
for fname in train_df[img_col]: split_lookup[fname] = "Train"
for fname in val_df[img_col]:   split_lookup[fname] = "Val"
for fname in test_df[img_col]:  split_lookup[fname] = "Test"

print(f"Split → Train: {len(train_df)} | Val: {len(val_df)} | Test: {len(test_df)}")

# Ground truth lookup
gt_lookup = dict(zip(df[img_col], df[score_col]))

# ─────────────────────────────────────────────
# MODEL
# ─────────────────────────────────────────────
class MobileNetV2Regressor(nn.Module):
    def __init__(self):
        super().__init__()
        backbone      = models.mobilenet_v2(weights=None)
        self.features = backbone.features
        self.pool     = nn.AdaptiveAvgPool2d(1)
        self.head     = nn.Sequential(
            nn.Flatten(),
            nn.Dropout(0.3),
            nn.Linear(1280, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x)
        x = self.head(x)
        return x.squeeze(1)


model = MobileNetV2Regressor().to(DEVICE)
model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE))
model.eval()
print(f"✅ Model loaded from: {MODEL_PATH}")

# ─────────────────────────────────────────────
# TRANSFORM
# ─────────────────────────────────────────────
transform = transforms.Compose([
    transforms.Resize((IMG_SIZE, IMG_SIZE)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                         std =[0.229, 0.224, 0.225]),
])

# ─────────────────────────────────────────────
# PREDICT FUNCTION
# ─────────────────────────────────────────────
def predict_image(img_path: str) -> float:
    img    = Image.open(img_path).convert("RGB")
    tensor = transform(img).unsqueeze(0).to(DEVICE)
    with torch.no_grad():
        norm_score = model(tensor).item()
    return round(norm_score * (SCORE_MAX - SCORE_MIN) + SCORE_MIN, 4)

# ─────────────────────────────────────────────
# BATCH PREDICT SEMUA GAMBAR + LABEL SPLIT
# ─────────────────────────────────────────────
print("\n── Batch Prediction (All Images) ──")
results   = []
valid_ext = {".jpg", ".jpeg", ".png", ".bmp"}

for fname in tqdm(sorted(os.listdir(PREDICT_DIR)), desc="Predicting", unit="img"):
    if Path(fname).suffix.lower() not in valid_ext:
        continue
    full_path = os.path.join(PREDICT_DIR, fname)
    try:
        pred  = predict_image(full_path)
        gt    = gt_lookup.get(fname, None)
        split = split_lookup.get(fname, "Unknown")
        results.append({
            "Image"          : fname,
            "Split"          : split,
            "Ground_Truth"   : round(float(gt), 4) if gt is not None else None,
            "Predicted_Score": pred,
            "Abs_Error"      : round(abs(pred - float(gt)), 4) if gt is not None else None
        })
    except Exception as e:
        print(f"  ⚠ Skipped {fname}: {e}")

result_df = pd.DataFrame(results)

# Save full predictions CSV
out_csv = os.path.join(os.path.dirname(MODEL_PATH), "predictions_all.csv")
result_df.to_csv(out_csv, index=False)
print(f"\n✅ All predictions saved → {out_csv}")
print(result_df.to_string(index=False))

# ─────────────────────────────────────────────
# EVALUATION METRICS — VAL & TEST SAHAJA
# ─────────────────────────────────────────────
def eval_metrics(subset_df):
    gt   = subset_df["Ground_Truth"].values.astype(float)
    pred = subset_df["Predicted_Score"].values.astype(float)
    mae  = np.mean(np.abs(pred - gt))
    rmse = np.sqrt(np.mean((pred - gt) ** 2))
    r2   = r2_score(gt, pred)
    return mae, rmse, r2

val_df_r  = result_df[result_df["Split"] == "Val"]
test_df_r = result_df[result_df["Split"] == "Test"]

val_mae,  val_rmse,  val_r2  = eval_metrics(val_df_r)
test_mae, test_rmse, test_r2 = eval_metrics(test_df_r)

print(f"\n{'='*50}")
print(f"  EVALUATION RESULTS")
print(f"{'='*50}")
print(f"  {'Metric':<10} {'Val':>10} {'Test':>10}")
print(f"  {'-'*30}")
print(f"  {'MAE':<10} {val_mae:>10.4f} {test_mae:>10.4f}")
print(f"  {'RMSE':<10} {val_rmse:>10.4f} {test_rmse:>10.4f}")
print(f"  {'R²':<10} {val_r2:>10.4f} {test_r2:>10.4f}")
print(f"  {'N':<10} {len(val_df_r):>10} {len(test_df_r):>10}")
print(f"{'='*50}")

# ─────────────────────────────────────────────
# VISUALIZE 5 RANDOM DARI TEST SET
# ─────────────────────────────────────────────
print("\n── Visualize 5 Random Test Samples ──")

test_results = result_df[result_df["Split"] == "Test"].to_dict("records")
random.seed(SEED)
sample_5     = random.sample(test_results, min(5, len(test_results)))

fig, axes = plt.subplots(1, 5, figsize=(20, 5))
fig.suptitle(
    f"Test Set — Predicted vs Ground Truth  |  MAE={test_mae:.4f}  RMSE={test_rmse:.4f}  R²={test_r2:.4f}",
    fontsize=12, fontweight="bold"
)

for ax, item in zip(axes, sample_5):
    fname      = item["Image"]
    pred_score = item["Predicted_Score"]
    gt_score   = item["Ground_Truth"]
    error      = item["Abs_Error"]

    img = Image.open(os.path.join(PREDICT_DIR, fname)).convert("RGB")
    ax.imshow(img)
    ax.axis("off")

    color = "green" if error < 0.5 else "red"
    title = (f"{fname}\n"
             f"GT   : {gt_score:.4f}\n"
             f"Pred : {pred_score:.4f}\n"
             f"Err  : {error:.4f}")
    ax.set_title(title, fontsize=9, color=color)

plt.tight_layout()
out_fig = os.path.join(os.path.dirname(MODEL_PATH), "test_sample_predictions.png")
plt.savefig(out_fig, dpi=150, bbox_inches="tight")
plt.show()
print(f"✅ Visualization saved → {out_fig}")
# Out:
# Device: cuda
# Score range: 2.040 → 7.690
# Split → Train: 597 | Val: 75 | Test: 75
# ✅ Model loaded from: C:\Users\PC\Desktop\Image_Regresion\outputs\best_model.pth
#
# ── Batch Prediction (All Images) ──
# Predicting: 100%|██████████| 747/747 [00:28<00:00, 26.22img/s]
# ✅ All predictions saved → C:\Users\PC\Desktop\Image_Regresion\outputs\predictions_all.csv
#      Image Split  Ground_Truth  Predicted_Score  Abs_Error
#    0_0.jpg Train          6.18           6.4445     0.2645
#  100_0.jpg Train          4.77           4.8313     0.0613
#  100_1.jpg  Test          5.23           6.2322     1.0022
#  100_2.jpg   Val          6.57           6.1978     0.3722
#  100_3.jpg Train          4.37           5.9404     1.5704
#  100_4.jpg Train          6.03           6.2691     0.2391
#  100_5.jpg Train          6.15           5.9737     0.1763
#  100_6.jpg Train          6.60           6.2141     0.3859
#  100_7.jpg Train          6.67           6.8087     0.1387
#  100_8.jpg Train          6.53           6.6102     0.0802
#  100_9.jpg Train          5.31           5.2852     0.0248
#  101_0.jpg Train          3.37           3.8134     0.4434
#  102_0.jpg Train          5.73           5.4002     0.3298
#  102_1.jpg Train          6.09           6.2472     0.1572
#  103_0.jpg Train          6.70           6.8662     0.1662
#  103_1.jpg Train          5.35           6.0403     0.6903
#  104_0.jpg Train          4.52           4.7704     0.2504
#  104_1.jpg   Val          6.32           6.3528     0.0328
#  104_2.jpg Train          5.42           5.5666     0.1466
#  104_3.jpg Train          6.07           6.3190     0.2490
#  104_4.jpg Train          5.90           5.7006     0.1994
#  104_5.jpg Train          5.75           6.1433     0.3933
#  104_6.jpg  Test          4.45           4.6238     0.1738
#  105_0.jpg Train          7.03           6.8546     0.1754
#  105_1.jpg Train          3.89           4.7620     0.8720
#  106_0.jpg Train          5.24           5.1871     0.0529
#  107_0.jpg   Val          6.67           5.8822     0.7878
#  107_1.jpg   Val          3.94           3.9634     0.0234
#  107_2.jpg Train          3.73           4.3859     0.6559
#  108_0.jpg Train          6.13           6.6148     0.4848
#  108_1.jpg Train          7.28           6.9711     0.3089
#  108_2.jpg Train          5.95           6.2645     0.3145
#  108_3.jpg Train          6.60           6.6860     0.0860
#  108_4.jpg Train          5.52           6.5935     1.0735
#  109_0.jpg Train          6.42           6.4602     0.0402
#   82_1.jpg Train          4.38           4.7562     0.3762
#   83_0.jpg Train          6.56           6.8922     0.3322
#   83_1.jpg Train          4.15           4.4835     0.3335
#   84_0.jpg Train          4.27           5.0302     0.7602
#   84_1.jpg Train          5.88           5.9410     0.0610
#   85_0.jpg Train          6.13           6.5157     0.3857
#   86_0.jpg Train          6.92           7.0809     0.1609
#   86_1.jpg Train          6.92           7.0809     0.1609
#   87_0.jpg   Val          6.45           6.7773     0.3273
#   87_1.jpg  Test          5.85           5.3778     0.4722
#   87_2.jpg Train          7.39           7.2091     0.1809
#   87_3.jpg Train          6.36           6.1482     0.2118
#   87_4.jpg Train          6.73           6.9400     0.2100
#   87_5.jpg   Val          6.95           6.9590     0.0090
#   87_6.jpg Train          5.88           6.0125     0.1325
#   88_0.jpg Train          5.52           5.2646     0.2554
#   89_0.jpg Train          4.52           5.5154     0.9954
#    8_0.jpg Train          4.22           4.3341     0.1141
#    8_1.jpg Train          4.25           3.9775     0.2725
#    8_2.jpg Train          4.73           5.5064     0.7764
#    8_3.jpg Train          5.57           5.9578     0.3878
#   90_0.jpg Train          4.15           3.8870     0.2630
#   91_0.jpg Train          5.46           5.7044     0.2444
#   91_1.jpg Train          6.24           6.2338     0.0062
#   91_2.jpg Train          6.47           6.7712     0.3012
#   91_3.jpg Train          6.56           6.4498     0.1102
#   91_4.jpg Train          6.92           6.7749     0.1451
#   91_5.jpg Train          6.84           7.0958     0.2558
#   91_6.jpg   Val          5.90           5.9816     0.0816
#   91_7.jpg Train          6.19           6.3883     0.1983
#   92_0.jpg Train          6.76           6.6860     0.0740
#   92_1.jpg Train          5.26           5.4430     0.1830
#   93_0.jpg Train          6.21           6.0598     0.1502
#   93_1.jpg Train          7.03           6.8242     0.2058
#   94_0.jpg  Test          5.17           5.4624     0.2924
#   94_1.jpg Train          5.17           5.4624     0.2924
#   94_2.jpg Train          6.73           6.4633     0.2667
#   94_3.jpg Train          6.49           6.3455     0.1445
#   95_0.jpg Train          3.78           4.1507     0.3707
#   95_1.jpg Train          7.04           7.2398     0.1998
#   96_0.jpg Train          6.48           6.6758     0.1958
#   96_1.jpg Train          6.89           6.4751     0.4149
#   96_2.jpg Train          6.28           5.9302     0.3498
#   97_0.jpg Train          4.29           4.3832     0.0932
#   98_0.jpg Train          5.43           5.1416     0.2884
#   99_0.jpg Train          6.02           6.0015     0.0185
#   99_1.jpg Train          4.44           4.8571     0.4171
#   99_2.jpg   Val          4.10           4.4471     0.3471
#   99_3.jpg Train          4.48           4.8500     0.3700
#   99_4.jpg  Test          4.66           4.8138     0.1538
#   99_5.jpg Train          3.43           3.5253     0.0953
#    9_0.jpg Train          5.32           5.6981     0.3781
#    9_1.jpg Train          5.90           5.7983     0.1017
#
# ==================================================
#   EVALUATION RESULTS
# ==================================================
#   Metric            Val       Test
#   ------------------------------
#   MAE            0.3126     0.4239
#   RMSE           0.4286     0.5430
#   R²             0.7111     0.6852
#   N                  75         75
# ==================================================
#
# ── Visualize 5 Random Test Samples ──
# ✅ Visualization saved → C:\Users\PC\Desktop\Image_Regresion\outputs\test_sample_predictions.png
